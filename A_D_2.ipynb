# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis0104343/Analisis_de_datos_2026/blob/main/A_D_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df_sp=pd.read_csv("/content/drive/MyDrive/Data/finanzas_gspc.csv")

# %%
df_sp=df_sp.drop(columns=['Unnamed: 0'])

# %%
df_sp.head()
df_sp=df_sp.rename(columns={"Price":"Date"})

# %%
df_sp["Date"]=pd.to_datetime(df_sp["Date"])
df_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    500 non-null    datetime64[ns]
#  1   Close   500 non-null    float64
#  2   High    500 non-null    float64
#  3   Low     500 non-null    float64
#  4   Open    500 non-null    float64
#  5   Volume  500 non-null    float64
#  6   Rango   500 non-null    float64
#  7   Year    500 non-null    int64
#  8   Month   500 non-null    int64
#  9   Day     500 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 39.2 KB

# %%
import yfinance as yf
df_gold=yf.download("GC=F",start="2024-01-01",end="2026-01-01")
df_gold.head()
# Out:
# /tmp/ipython-input-4210527928.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_gold=yf.download("GC=F",start="2024-01-01",end="2026-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open Volume
# Ticker             GC=F         GC=F         GC=F         GC=F   GC=F
# Date
# 2024-01-02  2064.399902  2073.699951  2057.100098  2063.500000     61
# 2024-01-03  2034.199951  2044.000000  2034.199951  2034.199951     54
# 2024-01-04  2042.300049  2044.500000  2038.000000  2041.599976     88
# 2024-01-05  2042.400024  2048.100098  2042.400024  2044.500000     12
# 2024-01-08  2026.599976  2033.699951  2019.099976  2019.099976     10

# %%
df_gold.to_csv("/content/drive/MyDrive/Data/finanzas_gold.csv")

# %%
import pandas as pd
df_gold=pd.read_csv("/content/drive/MyDrive/Data/finanzas_gold.csv")

# %%
df_gold.head()
# Out:
#         Price              Close               High                Low  \
# 0      Ticker               GC=F               GC=F               GC=F
# 1        Date                NaN                NaN                NaN
# 2  2024-01-02   2064.39990234375  2073.699951171875   2057.10009765625
# 3  2024-01-03  2034.199951171875             2044.0  2034.199951171875
# 4  2024-01-04  2042.300048828125             2044.5             2038.0
#
#                  Open Volume
# 0                GC=F   GC=F
# 1                 NaN    NaN
# 2              2063.5     61
# 3   2034.199951171875     54
# 4  2041.5999755859375     88

# %%
df_gold.columns=["Date","Close","High","Low","Open","Volume"]
df_gold.head()
# Out:
#          Date              Close               High                Low  \
# 0      Ticker               GC=F               GC=F               GC=F
# 1        Date                NaN                NaN                NaN
# 2  2024-01-02   2064.39990234375  2073.699951171875   2057.10009765625
# 3  2024-01-03  2034.199951171875             2044.0  2034.199951171875
# 4  2024-01-04  2042.300048828125             2044.5             2038.0
#
#                  Open Volume
# 0                GC=F   GC=F
# 1                 NaN    NaN
# 2              2063.5     61
# 3   2034.199951171875     54
# 4  2041.5999755859375     88

# %%
df_gold=df_gold.iloc[2:,:].reset_index(drop=True)
df_gold.head()
# Out:
#          Date               Close               High                 Low  \
# 0  2024-01-02    2064.39990234375  2073.699951171875    2057.10009765625
# 1  2024-01-03   2034.199951171875             2044.0   2034.199951171875
# 2  2024-01-04   2042.300048828125             2044.5              2038.0
# 3  2024-01-05  2042.4000244140625   2048.10009765625  2042.4000244140625
# 4  2024-01-08  2026.5999755859375  2033.699951171875  2019.0999755859375
#
#                  Open Volume
# 0              2063.5     61
# 1   2034.199951171875     54
# 2  2041.5999755859375     88
# 3              2044.5     12
# 4  2019.0999755859375     10

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    504 non-null    object
#  1   Close   504 non-null    object
#  2   High    504 non-null    object
#  3   Low     504 non-null    object
#  4   Open    504 non-null    object
#  5   Volume  504 non-null    object
# dtypes: object(6)
# memory usage: 23.8+ KB

# %%
df_gold["Date"]=pd.to_datetime(df_gold["Date"])
df_gold["Close"]=df_gold.Close.astype("float")
df_gold["High"]=df_gold.High.astype("float")
df_gold["Low"]=df_gold.Low.astype("float")
df_gold["Open"]=df_gold.Open.astype("float")
df_gold["Volume"]=df_gold.Volume.astype("float")
df_gold.tail(10)
# Out:
#           Date        Close         High          Low         Open  Volume
# 494 2025-12-17  4347.500000  4351.399902  4308.500000  4308.500000  2169.0
# 495 2025-12-18  4339.500000  4348.100098  4328.200195  4331.000000   705.0
# 496 2025-12-19  4361.399902  4361.399902  4350.100098  4350.100098  1065.0
# 497 2025-12-22  4444.600098  4447.600098  4371.100098  4371.100098   449.0
# 498 2025-12-23  4482.799805  4503.799805  4450.399902  4503.299805   694.0
# 499 2025-12-24  4480.600098  4503.399902  4468.399902  4500.700195   500.0
# 500 2025-12-26  4529.100098  4556.299805  4502.000000  4512.000000   263.0
# 501 2025-12-29  4325.100098  4379.000000  4325.100098  4371.500000  2044.0
# 502 2025-12-30  4370.100098  4403.600098  4338.000000  4346.399902  1837.0
# 503 2025-12-31  4325.600098  4363.799805  4285.000000  4333.500000   785.0

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    504 non-null    datetime64[ns]
#  1   Close   504 non-null    float64
#  2   High    504 non-null    float64
#  3   Low     504 non-null    float64
#  4   Open    504 non-null    float64
#  5   Volume  504 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 23.8 KB

# %%
df_mesc=df_sp.merge(df_gold,how="inner",left_on=["Date"],right_on=["Date"],suffixes=("_sp500","_gold"))

# %%
df_mesc.to_csv("/content/drive/MyDrive/Data/finanzas_comb.csv")

# %%
df_sp.to_csv("/content/drive/MyDrive/Data/finanzas_gspc.csv")

# %%
df_gold.to_csv("/content/drive/MyDrive/Data/finanzas_gold.csv")

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  504 non-null    int64
#  1   Date        504 non-null    object
#  2   Close       504 non-null    float64
#  3   High        504 non-null    float64
#  4   Low         504 non-null    float64
#  5   Open        504 non-null    float64
#  6   Volume      504 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 27.7+ KB

# %%
df_gold["Close"].mean()
# Out:
# np.float64(2918.6773761567615)

# %%
df_gold["Close"].median()

# %%
df_gold["Close"].std()

# %%
df_gold["Close"].min()

# %%
df_gold["Close"].max()

# %%
import matplotlib.pyplot as plt
import seaborn as sea

# %%
plt.figure(figsize=(10,5))
sea.histplot(df_gold("Close").bins=40,kde=True)

# %%
plt.figure(figsize=(8,5))
sea.boxplot(x=df_gold["Close"])
plt.xlabel("Precio")
plt.ylabel("Si")
plt.show()

# %%
df_gold.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# Close         0
# High          0
# Low           0
# Open          0
# Volume        0
# dtype: int64

# %%
df_gold.dropna()
# Out:
#      Unnamed: 0        Date        Close         High          Low  \
# 0             0  2024-01-02  2064.399902  2073.699951  2057.100098
# 1             1  2024-01-03  2034.199951  2044.000000  2034.199951
# 2             2  2024-01-04  2042.300049  2044.500000  2038.000000
# 3             3  2024-01-05  2042.400024  2048.100098  2042.400024
# 4             4  2024-01-08  2026.599976  2033.699951  2019.099976
# ..          ...         ...          ...          ...          ...
# 499         499  2025-12-24  4480.600098  4503.399902  4468.399902
# 500         500  2025-12-26  4529.100098  4556.299805  4502.000000
# 501         501  2025-12-29  4325.100098  4379.000000  4325.100098
# 502         502  2025-12-30  4370.100098  4403.600098  4338.000000
# 503         503  2025-12-31  4325.600098  4363.799805  4285.000000
#
#             Open  Volume
# 0    2063.500000    61.0
# 1    2034.199951    54.0
# 2    2041.599976    88.0
# 3    2044.500000    12.0
# 4    2019.099976    10.0
# ..           ...     ...
# 499  4500.700195   500.0
# 500  4512.000000   263.0
# 501  4371.500000  2044.0
# 502  4346.399902  1837.0
# 503  4333.500000   785.0
#
# [504 rows x 7 columns]

# %%
df_gold["Close"].fillna(df_gold["Close"].mean())

# %%
import numpy as np

# %%
plt.figure(figsize=(8,5))
sea.boxplot(x=df_gold["Volume"])
plt.xlabel("Precio")
plt.ylabel("Si")
plt.show()

# %%
Q1=df_gold["Volume"].quantile(0.25)
Q3=df_gold["Volume"].quantile(0.75)
IQR=Q3-Q1

# %%
prop=1.5
li=Q1-prop*IQR
ls=Q1+prop*IQR

# %%
df_outlier=df_gold.loc[(df_gold.Volume<li) | (df_gold.Volume>ls)]

# %%
df_outlier.shape
# Out:
# (94, 7)

# %%
df_clean=df_gold[(df_gold.Volume>li) & (df_gold.Volume<ls)]

# %%
df_clean
plt.figure(figsize=(8,5))
sea.boxplot(x=df_clean["Volume"])
plt.xlabel("Precio")
plt.ylabel("Si")
plt.show()

# %%
df_gold.Volume.mean()
# Out:
# np.float64(4275.958333333333)

# %%
df_clean.Volume.mean()
# Out:
# np.float64(436.38048780487804)

# %%
corr_matrix=df_gold[["Open","High","Low","Close","Volume"]].corr()

# %%
corr_matrix
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999563  0.999347  0.998842 -0.023602
# High    0.999563  1.000000  0.999309  0.999451 -0.025616
# Low     0.999347  0.999309  1.000000  0.999635 -0.020919
# Close   0.998842  0.999451  0.999635  1.000000 -0.023133
# Volume -0.023602 -0.025616 -0.020919 -0.023133  1.000000

# %%
plt.figure(figsize=(8,6))
sea.heatmap(corr_matrix,annot=True,vmin=-1,vmax=1,cmap="coolwarm_r",linewidths=0.2)
# Out:
# <Axes: >

# %%
#Revisar correlaciones https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html

# %%
import plotly.express as px

# %%
fig=px.scatter_matrix

# %%
fig.show()
