# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis0104343/Analisis_de_datos_2026/blob/main/%5Csi%5CC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as ran
num=ran.randrange(1,10)
print(num)
h=True
while h==True:
  numero=int(input("adivina el numero:"))

  if numero==0:
    break
  elif numero==num:
    print("felicidades adivinaste el numero")
    break
  else:
    continue
# Out:
# 7
# adivina el numero:7
# felicidades adivinaste el numero
