# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis0104343/Analisis_de_datos_2026/blob/main/Basicos_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas=[1,2,"letras",2,5,True]

# %%
hola=[4,8]

# %%
frutas+hola
# Out:
# [1, 2, 'letras', 2, 5, True, 4, 8]

# %%
frutras,append,extend,remove,pop,index,count

# %%
numeros=[3,1,4,5,10,2,14]
numeros.sort()
numeros
# Out:
# [1, 2, 3, 4, 5, 10, 14]

# %%
3 in numeros
# Out:
# True

# %%
frutas.clear()
frutas
# Out:
# []

# %%
tupla=(1,2,3,4,5)

# %%
vacio=set()
comj={1,2,3,4,5,5}
comj
comj.add(8)
comj.remove(4)
comj.discard3#seguro
# Out:
# {1, 2, 3, 4, 5}

# %%
from typing import Union

c1={1,2,3,4}
c2={4,5,6,7}
c1 & c2
c1|c2
c1-c2
c1-Union()
c1.add()
c1.difference
c1.issubset(c2)
c1.sime
# Out:
# {1, 2, 3}

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2,venn2_circles
A={1,2,3}
B={3,4,5}
plt.figure(figsize=(6,6))
venn=venn2([A,B],{"A","B"})
plt.show()

# %%
dicc={
    "nombre":"alexis",
    "apellidos":"gonzalez ledesma",
    "estudiante":True
}
dicc
dicc.keys()
dic.values()
dic.items()
dicc.pop("estudiante")
dicc.clear(0#borrar todo)
# Out:
# dict_keys(['nombre', 'apellidos', 'estudiante'])

# %%
#cadenas
cad1="hola mi ciamo ales"
cad1.upper()
cad1.lower()
cad1[::2]
cad1.capitalize()
    cad1.title()
# Out:
# 'hl icaoae'

# %%
cad="Hola soy goku"
cad.find("goku")
cad.count("a")
cad.replace("a","e")
cad2="1 2 3 4 5 6 7"
cad.split(" ")
cad.reversed()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2446903216.py in <cell line: 0>()
#       5 cad2="1 2 3 4 5 6 7"
#       6 cad.split(" ")
# ----> 7 cad.reversed()
#
# AttributeError: 'str' object has no attribute 'reversed'

# %%
cad.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1671962.py in <cell line: 0>()
# ----> 1 cad.reversed()
#
# AttributeError: 'str' object has no attribute 'reversed'

# %%
import random as ran
num=ran.randrange(1,10)
print(num)
h=True
while h==True:
  numero=int(input("adivina el numero:"))

  if numero==0:
    break
  elif numero==num:
    print("felicidades adivinaste el numero")
    break
  else:
    continue
