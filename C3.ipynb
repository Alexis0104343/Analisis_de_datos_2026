# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis0104343/Analisis_de_datos_2026/blob/main/C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cuadrado=lambda x:x**2
cuadrado(2)
numeros=[1,2,3,4,5]
list(map(lambda x:x*2,numeros))
# Out:
# [2, 4, 6, 8, 10]

# %%
n2=[10,25,30,35,60]
list(filter(lambda x:x%2==0,n2))
# Out:
# [10, 30, 60]

# %%
from functools import reduce as re
re(lambda x,y:x+y,n2)
# Out:
# 160

# %%
def multiplicador(n):
  def mul(x):
    return x*n
  return mul
  doble=multiplicador(2)

# %%
def factorial(n):
  if n==0 or n==1:
    return 1
  else:
    return n*factorial(n-1)
factorial(6)
# Out:
# 720

# %%
def b_b(lista,num,inicio,fin):
  l=len(lista)
  if num >fin:
    return -1
  if num==lista[l/2]
    return l
  elif num>lista[l/2]:
    b_b(lista[])

# %%
def dividir(a,b):
  if b==0:
    raise ZeroDivisionError("No puedes dividir entre cero")
  return a/b
dividir(10,5)
# Out:
# 2.0
